# %% [markdown]
# # 0. Import Dependencies and Pretrained Model

# %%
# !pip install --upgrade tensorflow_hub
# Out:
# Requirement already up-to-date: tensorflow_hub in c:\users\varun\anaconda3\lib\site-packages (0.12.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.8.0 in c:\users\varun\anaconda3\lib\site-packages (from tensorflow_hub) (3.15.6)
# Requirement already satisfied, skipping upgrade: numpy>=1.12.0 in c:\users\varun\anaconda3\lib\site-packages (from tensorflow_hub) (1.18.2)
# Requirement already satisfied, skipping upgrade: six>=1.9 in c:\users\varun\anaconda3\lib\site-packages (from protobuf>=3.8.0->tensorflow_hub) (1.15.0)

# %%
# importing libraries
import tensorflow_hub as hub
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
# load the pretrained model
model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

# %% [markdown]
# # 1. Preprocess Image and Load

# %%
def load_image(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = img[tf.newaxis, :]
    return img

# %%
content_image = load_image('profile.jfif')
style_image = load_image('dali.jpeg')

# %% [markdown]
# # 2. Visualize Output

# %%
content_image.shape
# Out:
# TensorShape([1, 520, 413, 3])

# %%
plt.imshow(np.squeeze(content_image))
plt.show()

# %%
plt.imshow(np.squeeze(style_image))
plt.show()

# %% [markdown]
# # 3. Stylize Image

# %%
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]

# %%
plt.imshow(np.squeeze(stylized_image))
plt.show()

# %%
cv2.imwrite('generated_img.jpg', cv2.cvtColor(np.squeeze(stylized_image)*255, cv2.COLOR_BGR2RGB))
# Out:
# True
